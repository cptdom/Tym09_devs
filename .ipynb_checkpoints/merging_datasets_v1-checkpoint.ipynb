# %%
import os 
import pandas as pd
import re
import numpy as np

# %%
data = {}

for file in os.listdir('./data'):
    path = os.path.join('./data', file)
    name = re.search(r'[a-zA-Z]+', file)[0]
    data[name] = pd.read_csv(path)

# %%
data.keys()
# Out:
# dict_keys(['bezrealitky', 'idnes', 'prazskereality', 'remax', 'sreality'])

# %% [markdown]
# # BEZREALITKY

# %%
data['bezrealitky'].head()
# Out:
#                                                 link  \
# 0  https://www.bezrealitky.cz/nemovitosti-byty-do...
# 1  https://www.bezrealitky.cz/nemovitosti-byty-do...
# 2  https://www.bezrealitky.cz/nemovitosti-byty-do...
# 3  https://www.bezrealitky.cz/nemovitosti-byty-do...
# 4  https://www.bezrealitky.cz/nemovitosti-byty-do...
#
#                             title  \
# 0  Prodej bytu  2+kk bez realitky
# 1  Prodej bytu  2+kk bez realitky
# 2  Prodej bytu  2+kk bez realitky
# 3  Prodej bytu  1+kk bez realitky
# 4  Prodej bytu  2+kk bez realitky
#
#                                              address      id  size  area  \
# 0  Kabešova, Praha - Vysočany\n\n                ...  524984  2+kk    53
# 1  Sokolovská, Praha - Libeň\n\n                 ...  656801  2+kk    38
# 2  Peroutkova, Praha - Jinonice\n\n              ...  608161  2+kk    68
# 3  Peroutkova, Praha - Jinonice\n\n              ...  561292  1+kk    24
# 4  Českomoravská, Praha - Libeň\n\n              ...  654529  2+kk    42
#
#      price   city city_part   owner  ... balcony terrace basement  loggia  \
# 0  5100000  Praha  Vysočany  Osobní  ...   False    True    False   False
# 1  4557000  Praha     Libeň  Osobní  ...   False   False     True   False
# 2  5287000  Praha  Jinonice  Osobní  ...   False   False    False   False
# 3  2929000  Praha  Jinonice  Osobní  ...   False   False    False   False
# 4  5500000  Praha     Libeň  Osobní  ...    True   False     True   False
#
#    parking  elevator  garage  available_from  \
# 0    False      True   False    01. 09. 2021
# 1    False     False   False    31. 08. 2022
# 2    False     False   False    14. 05. 2020
# 3    False     False   False             NaN
# 4     True      True    True    01. 06. 2021
#
#                                          description         street
# 0  Prodej bytu 2+kk s terasou a předzahrádkou\n\n...       Kabešova
# 1  Byt č. 44 orientovaný na severovýchod o dispoz...     Sokolovská
# 2  Ubytovací jednotky ve vyhledávané lokalitě v P...     Peroutkova
# 3  Ubytovací jednotky ve vyhledávané lokalitě v P...     Peroutkova
# 4  - malý, útulný byt 2+KK\n- orientace západ\n- ...  Českomoravská
#
# [5 rows x 24 columns]

# %% [markdown]
# # PRAZSKE REALITY

# %%
data['prazskereality'].head()
# Out:
#                                                 link  \
# 0  https://www.prazskereality.cz/prostorny-hezky-...
# 1  https://www.prazskereality.cz/exkluzivne-nabiz...
# 2  https://www.prazskereality.cz/nabizim-k-prodej...
# 3  https://www.prazskereality.cz/prodej-luxusniho...
# 4  https://www.prazskereality.cz/v-soucasne-situa...
#
#                                        title  \
# 0       Byt na prodej, 2+1, Praha 3 - Žižkov
# 1  Byt na prodej, 4+kk, Praha 1 - Nové Město
# 2    Byt na prodej, 3+1, Praha 5 - Hlubočepy
# 3      Byt na prodej, 5+1, Praha 5 - Smíchov
# 4   Byt na prodej, 3+kk, Praha 2 - Vinohrady
#
#                                            address  \
# 0                    Praha 3 - Žižkov, Čajkovského
# 1                 Praha 1 - Nové Město, Soukenická
# 2      Praha 5 - Hlubočepy, 15 200, Lamačova 824/9
# 3     Praha 5 - Smíchov, 15 000, Holečkova 3331/35
# 4  Praha 2 - Vinohrady, 12 000, U Zvonařky 2536/1a
#
#                                          description     price     updated  \
# 0  Byt na prodej / 2+1 / 77 m2 - Byty na prodej t...   7700000  23.04.2021
# 1  Byt na prodej / 4+kk / 151 m2 - Byty na prodej...  19500000  23.04.2021
# 2  Byt na prodej / 3+1 / 74 m2 - Byty na prodej t...   6950000  23.04.2021
# 3  Byt na prodej / 5+1 / 277 m2 - Byty na prodej ...  29900000  23.04.2021
# 4  Byt na prodej / 3+kk / 71 m2 - Byty na prodej ...  12500000  23.04.2021
#
#    size  area   owner building_type  ... balcony  basement  elevator  \
# 0   2+1    77  osobní       cihlová  ...   False      True      True
# 1  4+kk   151  osobní       cihlová  ...   False      True      True
# 2   3+1    74  osobní      panelová  ...   False      True      True
# 3   5+1   277  osobní     skeletová  ...   False      True      True
# 4  3+kk    71  osobní     skeletová  ...   False     False      True
#
#    barrier_free  floor  penb  terrace   city_part   city              street
# 0         False      2     G    False      Žižkov  Praha         Čajkovského
# 1         False      6     G    False  Nové Město  Praha          Soukenická
# 2         False      3   NaN    False   Hlubočepy  Praha      Lamačova 824/9
# 3         False      2   NaN     True     Smíchov  Praha   Holečkova 3331/35
# 4         False      3   NaN    False   Vinohrady  Praha  U Zvonařky 2536/1a
#
# [5 rows x 22 columns]

# %% [markdown]
# # SREALITY

# %%
data['sreality'].head()
# Out:
#                                  title                           address  \
# 0  Prodej bytu 4+kk 154 m² (Podkrovní)  Hlubočepská, Praha 5 - Hlubočepy
# 1               Prodej bytu 1+kk 31 m²  Rohanské nábřeží, Praha - Karlín
# 2  Prodej bytu 4+kk 154 m² (Podkrovní)       Holubova, Praha 5 - Smíchov
# 3               Prodej bytu 2+kk 74 m²       Drtinova, Praha 5 - Smíchov
# 4               Prodej bytu 3+kk 76 m²        U stanice, Praha 6 - Liboc
#
#    area floor_area     price  \
# 0   154      154m2  12999000
# 1    31       30m2   4755000
# 2   154      154m2  12990000
# 3    74       74m2   8490000
# 4    76       76m2   9890000
#
#                                          description basement building_type  \
# 0  Velký světlý byt 4+kk se dvěma balkóny a sklep...     True       Cihlová
# 1  Dovolujeme si Vám nabídnout k prodeji byt 1+kk...      NaN     Skeletová
# 2  Působivý byt, který se rozprostírá přes celé p...      NaN       Cihlová
# 3  Prodej zajímavého mezonetového bytu s galerií ...      NaN       Cihlová
# 4  Projekt komorního bytového domu, ve kterém se ...     True       Cihlová
#
#   penb  floor  ...       gas loggia umistneni_objektu  \
# 0    C    3.0  ...  Plynovod    NaN               NaN
# 1    B    1.0  ...       NaN    NaN               NaN
# 2    E    3.0  ...       NaN    NaN               NaN
# 3  NaN    5.0  ...       NaN    NaN               NaN
# 4  NaN    3.0  ...  Plynovod    NaN               NaN
#
#                                 doprava             voda               odpad  \
# 0                      Silnice, Autobus  Dálkový vodovod  Veřejná kanalizace
# 1                          Silnice, MHD  Dálkový vodovod  Veřejná kanalizace
# 2  Vlak, Dálnice, Silnice, MHD, Autobus              NaN                 NaN
# 3  Vlak, Dálnice, Silnice, MHD, Autobus              NaN                 NaN
# 4  Vlak, Dálnice, Silnice, MHD, Autobus  Dálkový vodovod  Veřejná kanalizace
#
#    city_part   city            street  size
# 0  Hlubočepy  Praha       Hlubočepská  4+kk
# 1     Karlín  Praha  Rohanské nábřeží  1+kk
# 2    Smíchov  Praha          Holubova  4+kk
# 3    Smíchov  Praha          Drtinova  2+kk
# 4      Liboc  Praha         U stanice  3+kk
#
# [5 rows x 27 columns]

# %% [markdown]
# # IDNES

# %%
data['idnes'].head()
# Out:
#                                                 link                    title  \
# 0  https://reality.idnes.cz/detail/prodej/byt/pra...  Prodej bytu 4+kk 117 m²
# 1  https://reality.idnes.cz/detail/prodej/byt/pra...   Prodej bytu 3+kk 65 m²
# 2  https://reality.idnes.cz/detail/prodej/byt/pra...  Prodej bytu 4+kk 154 m²
# 3  https://reality.idnes.cz/detail/prodej/byt/pra...    Prodej bytu 1+1 37 m²
# 4  https://reality.idnes.cz/detail/prodej/byt/pra...    Prodej bytu 2+1 77 m²
#
#                                       address     price  \
# 0   U Sluncové, Praha 8 - Karlín, okres Praha  14592002
# 1          Wassermannova, Praha 5 - Hlubočepy   7348254
# 2            Hlubočepská, Praha 5 - Hlubočepy  12999000
# 3                Košická, Praha 10 - Vršovice   6290500
# 4  Čajkovského, Praha 3 - Žižkov, okres Praha   7700000
#
#                                          description  area building_type  \
# 0  Krásný nový byt 4+kk o podlahové ploše 116,90 ...   7.0       cihlová
# 1  Byt 3+kk o celkové rozloze 69,4 m2 s balkónem ...   5.0       smíšená
# 2  Velký světlý byt 4+kk se dvěma balkóny a sklep...   4.0       cihlová
# 3  Byt 1+1, 2. NP, 36.5m2, ulice Košická, U Havli...   7.0       cihlová
# 4  Prostorný, hezky světlý byt 2+1 v OV umístěný ...   7.0       cihlová
#
#              state building_state   owner  ... terrace locality  electricity  \
# 0      ve výstavbě            NaN  osobní  ...    True      NaN          NaN
# 1      ve výstavbě            NaN  osobní  ...   False      NaN          NaN
# 2       dobrý stav            NaN  osobní  ...   False      NaN          NaN
# 3  po rekonstrukci            NaN  osobní  ...   False      NaN         230V
# 4       dobrý stav            NaN  osobní  ...   False      NaN          NaN
#
#   parking             gas   equipment elevator                      penb  \
# 0     NaN       nezaveden  nezařízený     True                         B
# 1     NaN             NaN         NaN    False  B (vyhl. č. 78/2013 Sb.)
# 2     NaN             NaN  nezařízený    False  C (vyhl. č. 78/2013 Sb.)
# 3     NaN  veřejný přívod         NaN     True                         G
# 4     NaN         zaveden  nezařízený     True                         G
#
#   internet  size
# 0     True  4+kk
# 1    False  3+kk
# 2     True  4+kk
# 3    False   1+1
# 4    False   2+1
#
# [5 rows x 25 columns]

# %% [markdown]
# # REMAX

# %%
data['remax'].head()
# Out:
#    area     price                                        description basement  \
# 0    49   5150000  Hezký světlý byt 1+1 o ploše 49,6 m2 plus balk...      NaN
# 1    55   4490000  Exklusivně nabízíme byt DV 3+1/55m2 na Praze 4...      NaN
# 2    39   5200000  Dovoluji si Vám nabídnout jednotku o dispozici...      NaN
# 3    96  11750000  Exkluzivní nabídka bytu 3+1 (původní dispozice...      NaN
# 4    46   4300000  Exkluzivní nabídka prodeje bytu 2+kk v docházk...      NaN
#
#   building_type penb  floor  floor_max        state internet  ...  \
# 0       Smíšená    C      2          7  Velmi dobrý      NaN  ...
# 1      Panelová    G      2          4  Velmi dobrý      NaN  ...
# 2       Smíšená    D      1          6  Velmi dobrý      NaN  ...
# 3       Cihlová    G      3          6  Velmi dobrý      NaN  ...
# 4      Panelová    G      8          4  Velmi dobrý      NaN  ...
#
#    umistneni_objektu doprava voda       odpad obcanska_vybavenost  \
# 0       Centrum obce     NaN  NaN  Kanalizace                 NaN
# 1   Klidná část obce     NaN  NaN  Kanalizace                 NaN
# 2       Centrum obce     NaN  NaN  Kanalizace                 NaN
# 3       Centrum obce     NaN  NaN  Kanalizace                 NaN
# 4           Sídliště     NaN  NaN  Kanalizace                 NaN
#
#                                              address  size  city_part   city  \
# 0  ulice Wiedermannova,\n\t\t\t\t\t\t\t\t\t\tPrah...   1+1   Stodůlky  Praha
# 1  ulice Hurbanova,\n\t\t\t\t\t\t\t\t\t\tPraha 4\...   3+1        Krč  Praha
# 2  ulice Podolské nábřeží,\n\t\t\t\t\t\t\t\t\t\tP...  1+kk     Podolí  Praha
# 3  ulice Slezská,\n\t\t\t\t\t\t\t\t\t\tPraha 3\n\...   3+1  Vinohrady  Praha
# 4  ulice Hráského,\n\t\t\t\t\t\t\t\t\t\tPraha 4\n...  2+kk     Chodov  Praha
#
#              street
# 0     Wiedermannova
# 1         Hurbanova
# 2  Podolské nábřeží
# 3           Slezská
# 4          Hráského
#
# [5 rows x 28 columns]

# %% [markdown]
# # MERGING

# %%
# spojit datasety vertikalne
df = pd.concat([data['bezrealitky'], data['prazskereality'], data['sreality'], data['idnes'], data['remax']])

# %%
# dropnout zbytecne sloupce
cols_to_drop = ['title', 'id', 'obcanska_vybavenost', 'floor_area', 'available_from', 'updated', 'address']
df.drop(columns = cols_to_drop, inplace = True)

# %%
# vytvorit mapu slov, kde se snazim cislovku slovy prevest na cislo (integer)
num_wordings = ['první', 'druhé', 'třetí', 'čtvrté', 'páté', 'šesté', 'sedmé', 'osmé', 'deváté', 'desáté',
               'jedenácté', 'dvanácté', 'třinácté', 'čtrnácté', 'patnácté', 'šestnácté', 'sedmnácté', 'osmnácté',
               'devatenácté']
# mapping
mapping = {'první': 1, 'druhé': 2, 'třetí': 3, 'čtvrté': 4, 'páté': 5, 'šesté': 6, 'sedmé': 7, 'osmé': 8, 
           'deváté': 9, 'desáté': 10, 'jedenácté': 11, 'dvanácté': 12, 'třinácté': 13, 'čtrnácté': 14,
           'patnácté': 15, 'šestnácté': 16, 'sedmnácté': 17, 'osmnácté': 18, 'devatenácté': 19}

# funkce, co vyhodi bud 0 = prizemi, last = posledni patro, nebo cislovku patra z description
def get_floor(row):
    if 'poslední' in str(row).strip():
        patro = 'last'
    elif 'přízem' in str(row).strip():
        patro = '0'
    else:
        # hleda slovo "patr" a pred nimi cislovku nebo slovo s cislovkou
        patro = re.search(r'([\w]+)(\s)([\w.]+)(\s)(pat[řero]+)', row)
        
        # pokud regex naleze pattern, tedy slovo patro
        if patro is not None:
            
            # vlozit nalezeny patter do promenne
            patro = patro[0]
            
            # najit cislovku (integer)
            number = re.search(r'\d', patro)
            
            # pokud nalezneme cislovku, pak cislovka = patro
            if number is not None:
                patro = number[0]
                
            # pokud nenalezneme cislovku, pak
            else:
                
                # projet loopem slova z mappingu, tedy cislovky psany slovy
                for word in num_wordings:
                    if word in patro.strip():
                        patro = mapping[word]
                        break
    return patro

# aplikovat funkci vyse, vyplnit tedy missing values tim, co vyplivla
df['floor'].fillna(df['description'].apply(get_floor), inplace=True)

# %%
# pokud je v description zmineno slovo "sklep", pak vyhodi true, jinak vyhodi None (ne False, protoze
# neni jistota, ze absence zminky o sklepu znamena absenci sklepu)

def get_basement_from_description(row):
    basement = True if re.search(r'(sklep)+', row) is not None else None
    return basement

# nahradit missing values v basement tam, kde to lze vycist z desc
df['basement'].fillna(df['description'].apply(get_basement_from_description), inplace = True)

# %%
# pokud je v description zmineno slovo "garaz" nebo "garáž", pak vyhodi true, jinak vyhodi None (ne False, protoze
# neni jistota, ze absence zminky o garáže znamena absenci garáže)

def get_garage_from_description(row):
    garage = True if re.search(r'(garaz|garáž)+', row) is not None else None
    return garage

# nahradit missing values v basement tam, kde to lze vycist z desc
df['garage'].fillna(df['description'].apply(get_garage_from_description), inplace = True)

# %%
# pokud je v description zmineno slovo "výtah" nebo "vytah", pak vyhodi true, jinak vyhodi None (ne False, protoze
# neni jistota, ze absence zminky o garáže znamena absenci garáže)

def get_elevator_from_description(row):
    elevator = True if re.search(r'(vytah|výtah)+', row) is not None else None
    return elevator

# nahradit missing values v basement tam, kde to lze vycist z desc
df['elevator'].fillna(df['description'].apply(get_elevator_from_description), inplace = True)

# %%
#naplnit PENB, protoze neuvedene PENB (tedy nezname, neudelane) ze zakona musi byt oznaceno jako G, tedy nejhorsi

df['penb'].fillna('G', inplace = True)
